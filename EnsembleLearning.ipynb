# %% [markdown]
# <a href="https://colab.research.google.com/github/vigneshwarjayabal/AI_And_Ml/blob/main/EnsembleLearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**What is Ensemble Learning?**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
import plotly.express as px


df = pd.read_csv('/content/drive/MyDrive/diabetes_prediction_dataset.csv')

# %%
from sklearn.preprocessing import OrdinalEncoder

encoder = OrdinalEncoder()
df["gender"]=encoder.fit_transform(df[["gender"]])
df["smoking_history"]=encoder.fit_transform(df[["smoking_history"]])

# %%
df.isnull().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 3854

# %%
df.drop_duplicates(inplace= True,keep='first')

# %%
x=df.iloc[:,:-1]  #independent
y=df.iloc[:,-1]    #dependent

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((86531, 8), (9615, 8), (86531,), (9615,))

# %%
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier
model1=RandomForestClassifier().fit(x_train,y_train)
y_pred=model1.predict(x_test)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      8786
#            1       0.93      0.67      0.78       829
#
#     accuracy                           0.97      9615
#    macro avg       0.95      0.83      0.88      9615
# weighted avg       0.97      0.97      0.96      9615

# %% [markdown]
# #**RandomForestClassifier**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #**AdaBoostClassifier**

# %%
from sklearn.ensemble import AdaBoostClassifier
model2=AdaBoostClassifier().fit(x_train,y_train)
y_pred=model2.predict(x_test)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      8784
#            1       1.00      0.63      0.77       831
#
#     accuracy                           0.97      9615
#    macro avg       0.98      0.82      0.88      9615
# weighted avg       0.97      0.97      0.96      9615

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #**XGBClassifier**

# %%
from xgboost import XGBClassifier
model3=XGBClassifier().fit(x_train,y_train)
y_pred=model3.predict(x_test)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      8784
#            1       0.95      0.66      0.78       831
#
#     accuracy                           0.97      9615
#    macro avg       0.96      0.83      0.88      9615
# weighted avg       0.97      0.97      0.96      9615

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #**GradientBoostingClassifier**

# %%
from sklearn.ensemble import GradientBoostingClassifier
model4=GradientBoostingClassifier().fit(x_train,y_train)
y_pred=model4.predict(x_test)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      8786
#            1       0.99      0.67      0.80       829
#
#     accuracy                           0.97      9615
#    macro avg       0.98      0.83      0.89      9615
# weighted avg       0.97      0.97      0.97      9615

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #**Support Vector Classifier**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sklearn.svm import SVC
model5=SVC().fit(x_train,y_train)
y_pred=model5.predict(x_test)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      8786
#            1       1.00      0.37      0.54       829
#
#     accuracy                           0.95      9615
#    macro avg       0.97      0.68      0.75      9615
# weighted avg       0.95      0.95      0.93      9615
